# %%
import pandas as pd
import random

# %%
female = [
    "Cory",
    "Eileen feng",
    "晓玉",
    "Anna",
    "Limin",
    "Xiao Qi",
    "Belinda",
    "mida",
    "阿梅",
]

random.seed(1231)
random.shuffle(female)
female
# Out:
# ['mida',
#  '阿梅',
#  '晓玉',
#  'Eileen feng',
#  'Xiao Qi',
#  'Anna',
#  'Cory',
#  'Limin',
#  'Belinda']

# %%
male = [
    "Neal",
    "Jingchang",
    "JustinZ",
    "北方的郎",
    "Steven Z",
    "Bruce W.",
    "Shan",
    "Jason 卡城",
    "SteveD",
    "Shawn Li",
    "白羊"
]

random.seed(1231)
random.shuffle(male)
male
# Out:
# ['SteveD',
#  'Jason 卡城',
#  'JustinZ',
#  'Jingchang',
#  '白羊',
#  'Bruce W.',
#  '北方的郎',
#  'Neal',
#  'Steven Z',
#  'Shawn Li',
#  'Shan']

# %%
last2Members = [
    "Cory",
    "Limin",
    "Belinda",
    "Shan",
    "Louise",
    "Daisy",
]

random.seed(1231)
random.shuffle(last2Members)
last2Members
# Out:
# ['Daisy', 'Limin', 'Cory', 'Belinda', 'Louise', 'Shan']
